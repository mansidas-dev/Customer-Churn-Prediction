# %% [markdown]
# import the dependecies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import warnings
warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

import xgboost as xgb

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# data loading

# %%
df = pd.read_csv("/content/WA_Fn-UseC_-Telco-Customer-Churn (1).csv")
print("Shape:", df.shape)
df.head()
# Out:
# Shape: (7043, 21)
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges  \
# 0              Yes           Electronic check           29.85        29.85
# 1               No               Mailed check           56.95       1889.5
# 2              Yes               Mailed check           53.85       108.15
# 3               No  Bank transfer (automatic)           42.30      1840.75
# 4              Yes           Electronic check           70.70       151.65
#
#   Churn
# 0    No
# 1    No
# 2   Yes
# 3    No
# 4   Yes

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges  \
# 0              Yes           Electronic check           29.85        29.85
# 1               No               Mailed check           56.95       1889.5
# 2              Yes               Mailed check           53.85       108.15
# 3               No  Bank transfer (automatic)           42.30      1840.75
# 4              Yes           Electronic check           70.70       151.65
#
#   Churn
# 0    No
# 1    No
# 2   Yes
# 3    No
# 4   Yes

# %%
# Drop customerID
df = df.drop("customerID", axis=1)

# Convert TotalCharges → numeric
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors="coerce")
df["TotalCharges"].fillna(df["TotalCharges"].median(), inplace=True)

# Remove spaces
for col in df.select_dtypes("object").columns:
    df[col] = df[col].str.strip()

# %%
pd.set_option('display.max_columns', None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
#  16  PaymentMethod     7043 non-null   object
#  17  MonthlyCharges    7043 non-null   float64
#  18  TotalCharges      7043 non-null   float64
#  19  Churn             7043 non-null   object
# dtypes: float64(2), int64(2), object(16)
# memory usage: 1.1+ MB

# %%
# droping coustomerID column as this is not required for modelling

# %%
df.head(2)
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
#
#   PaperlessBilling     PaymentMethod  MonthlyCharges  TotalCharges Churn
# 0              Yes  Electronic check           29.85         29.85    No
# 1               No      Mailed check           56.95       1889.50    No

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
print(df['gender'].unique())
# Out:
# ['Female' 'Male']

# %%
print(df['SeniorCitizen'].unique())
# Out:
# [0 1]

# %%
# printing the unique in all the columns
numrical_feature_list = ['tenure', 'MonthlyCharges', 'TotalCharges']

for col in df.columns:
  print(col, df[col].unique)
  print('-'*50)
# Out:
# gender <bound method Series.unique of 0       Female
# 1         Male
# 2         Male
# 3         Male
# 4       Female
#          ...
# 7038      Male
# 7039    Female
# 7040    Female
# 7041      Male
# 7042      Male
# Name: gender, Length: 7043, dtype: object>
# --------------------------------------------------
# SeniorCitizen <bound method Series.unique of 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: SeniorCitizen, Length: 7043, dtype: int64>
# --------------------------------------------------
# Partner <bound method Series.unique of 0       Yes
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 7038    Yes
# 7039    Yes
# 7040    Yes
# 7041    Yes
# 7042     No
# Name: Partner, Length: 7043, dtype: object>
# --------------------------------------------------
# Dependents <bound method Series.unique of 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 7038    Yes
# 7039    Yes
# 7040    Yes
# 7041     No
# 7042     No
# Name: Dependents, Length: 7043, dtype: object>
# --------------------------------------------------
# tenure <bound method Series.unique of 0        1
# 1       34
# 2        2
# 3       45
# 4        2
#         ..
# 7038    24
# 7039    72
# 7040    11
# 7041     4
# 7042    66
# Name: tenure, Length: 7043, dtype: int64>
# --------------------------------------------------
# PhoneService <bound method Series.unique of 0        No
# 1       Yes
# 2       Yes
# 3        No
# 4       Yes
#        ...
# 7038    Yes
# 7039    Yes
# 7040     No
# 7041    Yes
# 7042    Yes
# Name: PhoneService, Length: 7043, dtype: object>
# --------------------------------------------------
# MultipleLines <bound method Series.unique of 0       No phone service
# 1                     No
# 2                     No
# 3       No phone service
# 4                     No
#               ...
# 7038                 Yes
# 7039                 Yes
# 7040    No phone service
# 7041                 Yes
# 7042                  No
# Name: MultipleLines, Length: 7043, dtype: object>
# --------------------------------------------------
# InternetService <bound method Series.unique of 0               DSL
# 1               DSL
# 2               DSL
# 3               DSL
# 4       Fiber optic
#            ...
# 7038            DSL
# 7039    Fiber optic
# 7040            DSL
# 7041    Fiber optic
# 7042    Fiber optic
# Name: InternetService, Length: 7043, dtype: object>
# --------------------------------------------------
# OnlineSecurity <bound method Series.unique of 0        No
# 1       Yes
# 2       Yes
# 3       Yes
# 4        No
#        ...
# 7038    Yes
# 7039     No
# 7040    Yes
# 7041     No
# 7042    Yes
# Name: OnlineSecurity, Length: 7043, dtype: object>
# --------------------------------------------------
# OnlineBackup <bound method Series.unique of 0       Yes
# 1        No
# 2       Yes
# 3        No
# 4        No
#        ...
# 7038     No
# 7039    Yes
# 7040     No
# 7041     No
# 7042     No
# Name: OnlineBackup, Length: 7043, dtype: object>
# --------------------------------------------------
# DeviceProtection <bound method Series.unique of 0        No
# 1       Yes
# 2        No
# 3       Yes
# 4        No
#        ...
# 7038    Yes
# 7039    Yes
# 7040     No
# 7041     No
# 7042    Yes
# Name: DeviceProtection, Length: 7043, dtype: object>
# --------------------------------------------------
# TechSupport <bound method Series.unique of 0        No
# 1        No
# 2        No
# 3       Yes
# 4        No
#        ...
# 7038    Yes
# 7039     No
# 7040     No
# 7041     No
# 7042    Yes
# Name: TechSupport, Length: 7043, dtype: object>
# --------------------------------------------------
# StreamingTV <bound method Series.unique of 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 7038    Yes
# 7039    Yes
# 7040     No
# 7041     No
# 7042    Yes
# Name: StreamingTV, Length: 7043, dtype: object>
# --------------------------------------------------
# StreamingMovies <bound method Series.unique of 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 7038    Yes
# 7039    Yes
# 7040     No
# 7041     No
# 7042    Yes
# Name: StreamingMovies, Length: 7043, dtype: object>
# --------------------------------------------------
# Contract <bound method Series.unique of 0       Month-to-month
# 1             One year
# 2       Month-to-month
# 3             One year
# 4       Month-to-month
#              ...
# 7038          One year
# 7039          One year
# 7040    Month-to-month
# 7041    Month-to-month
# 7042          Two year
# Name: Contract, Length: 7043, dtype: object>
# --------------------------------------------------
# PaperlessBilling <bound method Series.unique of 0       Yes
# 1        No
# 2       Yes
# 3        No
# 4       Yes
#        ...
# 7038    Yes
# 7039    Yes
# 7040    Yes
# 7041    Yes
# 7042    Yes
# Name: PaperlessBilling, Length: 7043, dtype: object>
# --------------------------------------------------
# PaymentMethod <bound method Series.unique of 0                Electronic check
# 1                    Mailed check
# 2                    Mailed check
# 3       Bank transfer (automatic)
# 4                Electronic check
#                   ...
# 7038                 Mailed check
# 7039      Credit card (automatic)
# 7040             Electronic check
# 7041                 Mailed check
# 7042    Bank transfer (automatic)
# Name: PaymentMethod, Length: 7043, dtype: object>
# --------------------------------------------------
# MonthlyCharges <bound method Series.unique of 0        29.85
# 1        56.95
# 2        53.85
# 3        42.30
# 4        70.70
#          ...
# 7038     84.80
# 7039    103.20
# 7040     29.60
# 7041     74.40
# 7042    105.65
# Name: MonthlyCharges, Length: 7043, dtype: float64>
# --------------------------------------------------
# TotalCharges <bound method Series.unique of 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7043, dtype: float64>
# --------------------------------------------------
# Churn <bound method Series.unique of 0        No
# 1        No
# 2       Yes
# 3        No
# 4       Yes
#        ...
# 7038     No
# 7039     No
# 7040     No
# 7041    Yes
# 7042     No
# Name: Churn, Length: 7043, dtype: object>
# --------------------------------------------------

# %%
print(df.isnull().sum())
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# Convert TotalCharges → numeric
df['TotalCharges'] = df['TotalCharges'].replace(' ', np.nan)
df['TotalCharges'] = df['TotalCharges'].astype(float)

# Remove spaces
for col in df.select_dtypes("object").columns:
    df[col] = df[col].str.strip()

# %%
binary_map = {"Yes":1, "No":0, "Male":1, "Female":0}

for col in df.select_dtypes("object").columns:
    if col == "Churn":
        continue
    if df[col].nunique() == 2:
        df[col] = df[col].map(binary_map)
    else:
        df = pd.get_dummies(df, columns=[col], drop_first=True)

df["Churn"] = df["Churn"].map({"No":0, "Yes":1})

# %%
X = df.drop("Churn", axis=1)
y = df["Churn"]

scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# %%
log_reg = LogisticRegression(max_iter=1000)
log_reg.fit(X_train, y_train)

pred_lr = log_reg.predict(X_test)
print("LR Accuracy:", accuracy_score(y_test, pred_lr))
print(classification_report(y_test, pred_lr))
# Out:
# LR Accuracy: 0.8069552874378992
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87      1035
#            1       0.66      0.57      0.61       374
#
#     accuracy                           0.81      1409
#    macro avg       0.75      0.73      0.74      1409
# weighted avg       0.80      0.81      0.80      1409

# %%
rf = RandomForestClassifier(n_estimators=200, random_state=42)
rf.fit(X_train, y_train)

pred_rf = rf.predict(X_test)
print("RF Accuracy:", accuracy_score(y_test, pred_rf))
print(classification_report(y_test, pred_rf))
# Out:
# RF Accuracy: 0.7877927608232789
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86      1035
#            1       0.63      0.49      0.55       374
#
#     accuracy                           0.79      1409
#    macro avg       0.73      0.69      0.71      1409
# weighted avg       0.78      0.79      0.78      1409

# %%
xgb_model = xgb.XGBClassifier(eval_metric='logloss', random_state=42)
xgb_model.fit(X_train, y_train)

pred_xgb = xgb_model.predict(X_test)
print("XGB Accuracy:", accuracy_score(y_test, pred_xgb))
print(classification_report(y_test, pred_xgb))
# Out:
# XGB Accuracy: 0.7856635911994322
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86      1035
#            1       0.61      0.54      0.57       374
#
#     accuracy                           0.79      1409
#    macro avg       0.72      0.71      0.71      1409
# weighted avg       0.78      0.79      0.78      1409

# %%
ann = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(1, activation='sigmoid')
])

ann.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

es = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

history = ann.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=64,
    callbacks=[es],
    verbose=1
)

ann_pred = (ann.predict(X_test) >= 0.5).astype(int)
print("ANN Accuracy:", accuracy_score(y_test, ann_pred))
print(classification_report(y_test, ann_pred))
# Out:
# Epoch 1/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7569 - loss: 0.4899 - val_accuracy: 0.7720 - val_loss: 0.4535
# Epoch 2/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7822 - loss: 0.4404 - val_accuracy: 0.7817 - val_loss: 0.4431
# Epoch 3/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8018 - loss: 0.4137 - val_accuracy: 0.7764 - val_loss: 0.4423
# Epoch 4/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7928 - loss: 0.4236 - val_accuracy: 0.7853 - val_loss: 0.4375
# Epoch 5/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8036 - loss: 0.4265 - val_accuracy: 0.7862 - val_loss: 0.4379
# Epoch 6/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7994 - loss: 0.4191 - val_accuracy: 0.7817 - val_loss: 0.4418
# Epoch 7/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8080 - loss: 0.4085 - val_accuracy: 0.7879 - val_loss: 0.4385
# Epoch 8/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8100 - loss: 0.4076 - val_accuracy: 0.7782 - val_loss: 0.4443
# Epoch 9/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8159 - loss: 0.3985 - val_accuracy: 0.7853 - val_loss: 0.4374
# Epoch 10/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8185 - loss: 0.3949 - val_accuracy: 0.7870 - val_loss: 0.4393
# Epoch 11/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8110 - loss: 0.4132 - val_accuracy: 0.7906 - val_loss: 0.4359
# Epoch 12/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8154 - loss: 0.3951 - val_accuracy: 0.7844 - val_loss: 0.4386
# Epoch 13/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8146 - loss: 0.4084 - val_accuracy: 0.7915 - val_loss: 0.4383
# Epoch 14/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8105 - loss: 0.4048 - val_accuracy: 0.7888 - val_loss: 0.4400
# Epoch 15/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8150 - loss: 0.3998 - val_accuracy: 0.7924 - val_loss: 0.4388
# Epoch 16/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8253 - loss: 0.3918 - val_accuracy: 0.7870 - val_loss: 0.4418
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# ANN Accuracy: 0.7920511000709723
#               precision    recall  f1-score   support
#
#            0       0.84      0.89      0.86      1035
#            1       0.63      0.53      0.57       374
#
#     accuracy                           0.79      1409
#    macro avg       0.73      0.71      0.72      1409
# weighted avg       0.78      0.79      0.79      1409

# %%
joblib.dump({
    "model": rf,
    "scaler": scaler,
    "columns": X.columns
}, "final_churn_model.pkl")

print("Saved: final_churn_model.pkl")
# Out:
# Saved: final_churn_model.pkl
